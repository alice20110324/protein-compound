# %%
import esm
protein_model, protein_alphabet = esm.pretrained.esm2_t33_650M_UR50D()
protein_model,protein_alphabet=esm.pretrained.load_state_dict(torch.load('esm2_t33_650M_UR50D.pt'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/esm-main1/esm/pretrained.py in load_hub_workaround(url)
#      32     try:
# ---> 33         data = torch.hub.load_state_dict_from_url(url, progress=False, map_location="cpu")
#      34     except RuntimeError:
#
# ~/miniconda3/lib/python3.8/site-packages/torch/hub.py in load_state_dict_from_url(url, model_dir, map_location, progress, check_hash, file_name)
#     734         return _legacy_zip_load(cached_file, model_dir, map_location)
# --> 735     return torch.load(cached_file, map_location=map_location)
#
# ~/miniconda3/lib/python3.8/site-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     776             orig_position = opened_file.tell()
# --> 777             with _open_zipfile_reader(opened_file) as opened_zipfile:
# ...
